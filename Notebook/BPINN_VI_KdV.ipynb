# %%
import copy
import math
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Optimizer

import scipy.io
from model import BayesLinear_Normalq, BBP_Model
from utils import log_gaussian_loss, gaussian, get_kl_Gaussian_divergence

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('device: {}'.format(device))
# Out:
# device: cuda

# %%
class BBP_Model_PINN:
    def __init__(self, xt_lb, xt_ub, u_lb, u_ub,
                 input_dim, output_dim, no_units,
                 learn_rate, batch_size, no_batches,
                 prior_lambda1, prior_lambda2, num_epochs):

        
        self.xt_lb = torch.from_numpy(xt_lb).float().to(device)
        self.xt_ub = torch.from_numpy(xt_ub).float().to(device)
        self.u_lb = torch.from_numpy(u_lb).float().to(device)
        self.u_ub = torch.from_numpy(u_ub).float().to(device)


        self.learn_rate = learn_rate
        self.batch_size = batch_size
        self.no_batches = no_batches

        self.network = BBP_Model(input_dim = input_dim, output_dim = output_dim,
                                    no_units = no_units)


        self.prior_lambda1 = prior_lambda1
        self.prior_lambda2 = prior_lambda2

        self.lambda1_mus = nn.Parameter(torch.Tensor(1).uniform_(0, 2))
        self.lambda1_rhos = nn.Parameter(torch.Tensor(1).uniform_(-3, 2))
        self.lambda2_mus = nn.Parameter(torch.Tensor(1).uniform_(0, 0.05))
        self.lambda2_rhos = nn.Parameter(torch.Tensor(1).uniform_(-3, -2))

        self.network.register_parameter('lambda1_mu', self.lambda1_mus)
        self.network.register_parameter('lambda2_mu', self.lambda2_mus)
        self.network.register_parameter('lambda1_rho', self.lambda1_rhos)
        self.network.register_parameter('lambda2_rho', self.lambda2_rhos)

        self.network = self.network.to(device)

        # self.optimizer = torch.optim.SGD(self.network.parameters(), lr = self.learn_rate)
        self.optimizer = torch.optim.AdamW(self.network.parameters(), lr = self.learn_rate)
        # self.scheduler = torch.optim.lr_scheduler.OneCycleLR(self.optimizer, max_lr = 1e-3, 
        #                                     steps_per_epoch = no_batches, epochs = num_epochs)
        self.loss_func = log_gaussian_loss

    def net_U(self, x, t):
        xt = torch.cat((x,t), dim=1)
        xt = 2*(xt-self.xt_lb)/(self.xt_ub-self.xt_lb) - 1
        out, KL_loss = self.network(xt)

        u = out[:,0:1]
        log_noise_u = out[:,1:2]
        
        return u, log_noise_u, KL_loss

    def net_F(self, x, t, lambda1_sample, lambda2_sample):
        lambda_1 = lambda1_sample        
        lambda_2 = torch.exp(lambda2_sample)

        u, _, _ = self.net_U(x, t)
        u = u*(self.u_ub-self.u_lb) + self.u_lb # reverse scaling
        # u = u*self.u_std + self.u_mean

        u_t = torch.autograd.grad(u, t, torch.ones_like(u),
                                    retain_graph=True,
                                    create_graph=True)[0]
                                    
        u_x = torch.autograd.grad(u, x, torch.ones_like(u),
                                    retain_graph=True,
                                    create_graph=True)[0]

        u_xx = torch.autograd.grad(u_x, x, torch.ones_like(u_x),
                                    retain_graph=True,
                                    create_graph=True)[0]

        u_xxx = torch.autograd.grad(u_xx, x, torch.ones_like(u_xx),
                                    retain_graph=True,
                                    create_graph=True)[0]

        F = u_t + lambda_1*u*u_x + lambda_2*u_xxx
        return F

    def fit(self, X, t, U, no_samples):
        self.network.train()

        U = (U-self.u_lb)/(self.u_ub-self.u_lb) # scaling
      

        # reset gradient and total loss
        self.optimizer.zero_grad()

        fit_loss_total = 0
        fit_loss_F_total = 0
        fit_loss_U_total = 0

        for i in range(no_samples):
            lambda1_epsilons = self.lambda1_mus.data.new(self.lambda1_mus.size()).normal_()
            lambda1_stds = torch.log(1 + torch.exp(self.lambda1_rhos))
            lambda2_epsilons = self.lambda2_mus.data.new(self.lambda2_mus.size()).normal_()
            lambda2_stds = torch.log(1 + torch.exp(self.lambda2_rhos))

            lambda1_sample = self.lambda1_mus + lambda1_epsilons * lambda1_stds
            lambda2_sample = self.lambda2_mus + lambda2_epsilons * lambda2_stds

            u_pred, log_noise_u, KL_loss_para = self.net_U(X, t)
            f_pred = self.net_F(X, t, lambda1_sample, lambda2_sample)

            # calculate fit loss based on mean and standard deviation of output
            fit_loss_U_total += self.loss_func(u_pred, U, log_noise_u.exp(), self.network.output_dim)
            fit_loss_F_total += torch.sum(f_pred**2) ######
            # fit_loss_F_total += self.loss_func(f_pred, torch.zeros_like(f_pred), self.network.log_noise_f.exp(), self.network.output_dim)

        KL_loss_lambda1 = get_kl_Gaussian_divergence(self.prior_lambda1.mu, self.prior_lambda1.sigma**2, self.lambda1_mus, lambda1_stds**2)
        KL_loss_lambda2 = get_kl_Gaussian_divergence(self.prior_lambda2.mu, self.prior_lambda2.sigma**2, self.lambda2_mus, lambda2_stds**2)
        KL_loss_total = KL_loss_para + KL_loss_lambda1 + KL_loss_lambda2

        # minibatches and KL reweighting
        KL_loss_total = KL_loss_total/self.no_batches
        total_loss = (KL_loss_total + fit_loss_U_total + fit_loss_F_total) / (no_samples*X.shape[0])
        
        total_loss.backward()
        self.optimizer.step()
        # self.scheduler.step()

        return fit_loss_U_total/no_samples, fit_loss_F_total/no_samples, KL_loss_total, total_loss

    def predict(self, xt, no_sample, best_net):
        xt = torch.tensor(xt, requires_grad=True).float().to(device)
        xt = 2*(xt-self.xt_lb)/(self.xt_ub-self.xt_lb) - 1

        self.network.eval()
        samples = []
        noises = []
        for i in range(no_sample):
            out_pred, _ = best_net(xt)
            u_pred = out_pred[:,0:1]
            noise_u = out_pred[:,1:2].exp()

            u_pred = u_pred*(self.u_ub-self.u_lb) + self.u_lb # reverse scaling
            noise_u = noise_u*(self.u_ub-self.u_lb)

            samples.append(u_pred.detach().cpu().numpy())
            noises.append(noise_u.detach().cpu().numpy())
        return np.array(samples), np.array(noises)

    def sample_F(self, xt, no_samples = 100):
        xt = torch.tensor(xt, requires_grad=True).float().to(device)
        xt = 2*(xt-self.xt_lb)/(self.xt_ub-self.xt_lb) - 1
        self.network.eval()

        samples = []
        for _ in range(no_samples):
            lambda1_epsilons = self.lambda1_mus.data.new(self.lambda1_mus.size()).normal_()
            lambda1_stds = torch.log(1 + torch.exp(self.lambda1_rhos))
            lambda2_epsilons = self.lambda2_mus.data.new(self.lambda2_mus.size()).normal_()
            lambda2_stds = torch.log(1 + torch.exp(self.lambda2_rhos))

            lambda1_sample = self.lambda1_mus + lambda1_epsilons * lambda1_stds
            lambda2_sample = self.lambda2_mus + lambda2_epsilons * lambda2_stds
            f = self.net_F(xt[:,0:1], xt[:,1:2], lambda1_sample, lambda2_sample)
            samples.append(f.detach().cpu().numpy().ravel())
        return np.array(samples)

# %%
data = scipy.io.loadmat('../Data/KdV.mat')

t = data['tt'].flatten()[:,None] # 201 x 1
x = data['x'].flatten()[:,None] # 512 x 1
Exact_ = np.real(data['uu']).T # 201 x 512

noise = 0.01
Exact = Exact_ + noise*np.std(Exact_)*np.random.randn(201, 512)

X, T = np.meshgrid(x,t) # 201 x 512
X_star = np.hstack((X.flatten()[:,None], T.flatten()[:,None])) # 102912 x 2
u_star = Exact.flatten()[:,None]  # 102912 x 1

# Domain bounds of x, t
xt_lb = X_star.min(0)
xt_ub = X_star.max(0)

# training data
N_u = 2000
idx = np.random.choice(X_star.shape[0], N_u, replace = False)
X_u_train = X_star[idx,:]

u_train = u_star[idx,:]

u_min = u_train.min(0)
u_max = u_train.max(0)

num_epochs, batch_size = 25000, len(X_u_train),

net = BBP_Model_PINN(xt_lb, xt_ub, u_min, u_max,
                     input_dim = 2, output_dim = 2, no_units = 50, learn_rate = 1e-3,
                        batch_size = batch_size, no_batches = 1,
                        prior_lambda1 = gaussian(0, 1), prior_lambda2 = gaussian(0, 1), num_epochs = num_epochs)

# %%
fit_loss_U_train = np.zeros(num_epochs)
fit_loss_F_train = np.zeros(num_epochs)
KL_loss_train = np.zeros(num_epochs)
loss = np.zeros(num_epochs)
noise = []


X = torch.tensor(X_u_train[:,0:1], requires_grad = True, device = device).float()
t = torch.tensor(X_u_train[:,1:2], requires_grad = True, device = device).float()
U = torch.tensor(u_train, requires_grad = True, device = device).float()

X_u_test_25 = np.hstack([x, 0.25*np.ones_like((x))])
target_25 = Exact_[50].reshape(-1,1)

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter(comment = '_KdV')

for i in range(num_epochs):

    EU, EF, KL_loss, total_loss = net.fit(X, t, U, no_samples = 20)
    
    fit_loss_U_train[i] = EU.item()
    fit_loss_F_train[i] = EF.item()
    KL_loss_train[i] = KL_loss.item()
    loss[i] = total_loss.item()

    writer.add_scalar("loss/total_loss", loss[i], i)
    writer.add_scalar("loss/U_loss", fit_loss_U_train[i], i)
    writer.add_scalar("loss/F_loss", fit_loss_F_train[i], i)
    writer.add_scalar("loss/KL_loss", KL_loss_train[i], i)
    

    if i % 2000 == 0:
        F_test = net.sample_F(X_u_test_25)
        fig, axs = plt.subplots(2, 2, figsize=(20, 8))
        axs[0,0].hist(F_test[:,0])
        axs[0,1].hist(F_test[:,100])
        axs[1,0].hist(F_test[:,150])
        axs[1,1].hist(F_test[:,255])
        plt.savefig('./plots/kdv_epoch{}.tiff'.format(i))


    if i % 100 == 0 or i == num_epochs - 1:

        print("Epoch: {:5d}/{:5d}, total loss = {:.3f}, Fit loss U = {:.3f}, Fit loss F = {:.3f}, KL loss = {:.3f}".format(i + 1, num_epochs, 
               loss[i], fit_loss_U_train[i], fit_loss_F_train[i], KL_loss_train[i]))

    
        lambda1_mus = net.lambda1_mus.item()
        lambda1_stds = torch.log(1 + torch.exp(net.lambda1_rhos)).item()
        
        lambda2_mus = np.exp(net.lambda2_mus.item())
        lambda2_stds = torch.log(1 + torch.exp(net.lambda2_rhos)).item()
        
        samples_25, _ = net.predict(X_u_test_25, 100, net.network)
        u_pred_25 = samples_25.mean(axis = 0)
        error_25 = np.linalg.norm(target_25-u_pred_25, 2)/np.linalg.norm(target_25, 2)

        samples_train, _ = net.predict(X_u_train, 100, net.network)
        u_pred_train = samples_train.mean(axis = 0)
        error_train = np.linalg.norm(u_train-u_pred_train, 2)/np.linalg.norm(u_train, 2)


        # writer.add_scalars("loss/train_test", {'train':error_train, 'test':error_25}, i)
        # writer.add_scalars("loss/f_u", {'noise_f':noise_f, 'noise_u':noise_u}, i)
       
        print("Epoch: {:5d}/{:5d}, lambda1_mu = {:.3f}, lambda2_mu = {:.3f}, lambda1_std = {:.3f}, lambda2_std = {:.3f}".format(i + 1, num_epochs,
                                                                                                                        lambda1_mus, lambda2_mus,
                                                                                                                        lambda1_stds, lambda2_stds))
        print("Epoch: {:5d}/{:5d}, error_25 = {:.5f}, error_train = {:.5f}".format(i+1, num_epochs, error_25, error_train))
        # print("Epoch: {:5d}/{:5d}, noise_f = {:.5f}, noise_u = {:.5f}".format(i+1, num_epochs, noise_f, noise_u))
        print()

writer.close()
# Out:
# Epoch:     1/25000, total loss = 1.686, Fit loss U = 2032.945, Fit loss F = 6.122, KL loss = 26644.570
# Epoch:     1/25000, lambda1_mu = 1.732, lambda2_mu = 1.029, lambda1_std = 0.584, lambda2_std = 0.088
# Epoch:     1/25000, error_25 = 1.88301, error_train = 1.85268
#
# Epoch:   101/25000, total loss = 0.927, Fit loss U = 533.145, Fit loss F = 4.557, KL loss = 26328.172
# Epoch:   101/25000, lambda1_mu = 1.655, lambda2_mu = 1.000, lambda1_std = 0.564, lambda2_std = 0.096
# Epoch:   101/25000, error_25 = 1.02729, error_train = 1.05975
#
# Epoch:   201/25000, total loss = 0.765, Fit loss U = 218.781, Fit loss F = 2.620, KL loss = 26183.674
# Epoch:   201/25000, lambda1_mu = 1.606, lambda2_mu = 0.987, lambda1_std = 0.560, lambda2_std = 0.106
# Epoch:   201/25000, error_25 = 0.99969, error_train = 1.02026
#
# Epoch:   301/25000, total loss = 0.806, Fit loss U = 303.815, Fit loss F = 5.708, KL loss = 26039.668
# Epoch:   301/25000, lambda1_mu = 1.561, lambda2_mu = 0.975, lambda1_std = 0.558, lambda2_std = 0.116
# Epoch:   301/25000, error_25 = 0.99919, error_train = 1.00758
#
# Epoch:   401/25000, total loss = 0.733, Fit loss U = 168.756, Fit loss F = 2.525, KL loss = 25894.781
# Epoch:   401/25000, lambda1_mu = 1.508, lambda2_mu = 0.966, lambda1_std = 0.554, lambda2_std = 0.128
# Epoch:   401/25000, error_25 = 1.00083, error_train = 1.00080
#
# Epoch:   501/25000, total loss = 0.677, Fit loss U = 58.627, Fit loss F = 7.584, KL loss = 25749.570
# Epoch:   501/25000, lambda1_mu = 1.375, lambda2_mu = 0.937, lambda1_std = 0.537, lambda2_std = 0.135
# Epoch:   501/25000, error_25 = 0.99860, error_train = 0.99847
#
# Epoch:   601/25000, total loss = 0.666, Fit loss U = 48.931, Fit loss F = 2.233, KL loss = 25603.303
# Epoch:   601/25000, lambda1_mu = 1.210, lambda2_mu = 0.863, lambda1_std = 0.503, lambda2_std = 0.136
# Epoch:   601/25000, error_25 = 0.99972, error_train = 0.99692
#
# Epoch:   701/25000, total loss = 0.682, Fit loss U = 80.610, Fit loss F = 9.775, KL loss = 25460.150
# Epoch:   701/25000, lambda1_mu = 1.080, lambda2_mu = 0.818, lambda1_std = 0.478, lambda2_std = 0.137
# Epoch:   701/25000, error_25 = 0.99837, error_train = 0.99687
#
# Epoch:   801/25000, total loss = 0.639, Fit loss U = 8.970, Fit loss F = 3.470, KL loss = 25314.475
# Epoch:   801/25000, lambda1_mu = 0.971, lambda2_mu = 0.748, lambda1_std = 0.458, lambda2_std = 0.134
# Epoch:   801/25000, error_25 = 1.00120, error_train = 0.99710
#
# Epoch:   901/25000, total loss = 0.663, Fit loss U = 63.178, Fit loss F = 4.407, KL loss = 25166.633
# Epoch:   901/25000, lambda1_mu = 0.890, lambda2_mu = 0.689, lambda1_std = 0.442, lambda2_std = 0.130
# Epoch:   901/25000, error_25 = 0.99821, error_train = 0.99847
#
# Epoch:  1001/25000, total loss = 0.612, Fit loss U = -38.457, Fit loss F = 12.127, KL loss = 25018.717
# Epoch:  1001/25000, lambda1_mu = 0.809, lambda2_mu = 0.604, lambda1_std = 0.428, lambda2_std = 0.125
# Epoch:  1001/25000, error_25 = 0.99917, error_train = 0.99931
#
# Epoch:  1101/25000, total loss = 0.577, Fit loss U = -94.226, Fit loss F = 4.273, KL loss = 24874.369
# Epoch:  1101/25000, lambda1_mu = 0.710, lambda2_mu = 0.528, lambda1_std = 0.406, lambda2_std = 0.120
# Epoch:  1101/25000, error_25 = 1.00203, error_train = 1.00163
#
# Epoch:  1201/25000, total loss = 0.579, Fit loss U = -82.744, Fit loss F = 4.282, KL loss = 24734.094
# Epoch:  1201/25000, lambda1_mu = 0.604, lambda2_mu = 0.456, lambda1_std = 0.384, lambda2_std = 0.117
# Epoch:  1201/25000, error_25 = 1.00055, error_train = 1.00160
#
# Epoch:  1301/25000, total loss = 0.542, Fit loss U = -153.078, Fit loss F = 6.569, KL loss = 24601.361
# Epoch:  1301/25000, lambda1_mu = 0.504, lambda2_mu = 0.389, lambda1_std = 0.366, lambda2_std = 0.115
# Epoch:  1301/25000, error_25 = 1.01228, error_train = 1.01254
#
# Epoch:  1401/25000, total loss = 0.572, Fit loss U = -93.323, Fit loss F = 13.181, KL loss = 24473.229
# Epoch:  1401/25000, lambda1_mu = 0.393, lambda2_mu = 0.328, lambda1_std = 0.347, lambda2_std = 0.110
# Epoch:  1401/25000, error_25 = 1.01081, error_train = 1.01497
#
# Epoch:  1501/25000, total loss = 0.529, Fit loss U = -165.648, Fit loss F = 5.608, KL loss = 24350.443
# Epoch:  1501/25000, lambda1_mu = 0.298, lambda2_mu = 0.278, lambda1_std = 0.328, lambda2_std = 0.107
# Epoch:  1501/25000, error_25 = 1.00909, error_train = 1.00989
#
# Epoch:  1601/25000, total loss = 0.550, Fit loss U = -122.557, Fit loss F = 11.572, KL loss = 24235.039
# Epoch:  1601/25000, lambda1_mu = 0.169, lambda2_mu = 0.227, lambda1_std = 0.305, lambda2_std = 0.100
# Epoch:  1601/25000, error_25 = 1.01430, error_train = 1.01105
#
# Epoch:  1701/25000, total loss = 0.506, Fit loss U = -202.345, Fit loss F = 8.082, KL loss = 24127.006
# Epoch:  1701/25000, lambda1_mu = 0.051, lambda2_mu = 0.187, lambda1_std = 0.283, lambda2_std = 0.095
# Epoch:  1701/25000, error_25 = 1.01641, error_train = 1.00862
#
# Epoch:  1801/25000, total loss = 0.530, Fit loss U = -159.376, Fit loss F = 18.132, KL loss = 24027.062
# Epoch:  1801/25000, lambda1_mu = -0.048, lambda2_mu = 0.154, lambda1_std = 0.265, lambda2_std = 0.090
# Epoch:  1801/25000, error_25 = 1.00537, error_train = 1.00638
#
# Epoch:  1901/25000, total loss = 0.468, Fit loss U = -287.029, Fit loss F = 25.528, KL loss = 23940.668
# Epoch:  1901/25000, lambda1_mu = -0.138, lambda2_mu = 0.128, lambda1_std = 0.248, lambda2_std = 0.085
# Epoch:  1901/25000, error_25 = 0.99891, error_train = 1.00772
#
# Epoch:  2001/25000, total loss = 0.461, Fit loss U = -293.652, Fit loss F = 21.899, KL loss = 23856.543
# Epoch:  2001/25000, lambda1_mu = -0.220, lambda2_mu = 0.107, lambda1_std = 0.230, lambda2_std = 0.081
# Epoch:  2001/25000, error_25 = 1.00916, error_train = 1.00058
#
# Epoch:  2101/25000, total loss = 0.457, Fit loss U = -305.396, Fit loss F = 31.020, KL loss = 23778.240
# Epoch:  2101/25000, lambda1_mu = -0.275, lambda2_mu = 0.091, lambda1_std = 0.212, lambda2_std = 0.076
# Epoch:  2101/25000, error_25 = 1.00086, error_train = 1.00169
#
# Epoch:  2201/25000, total loss = 0.432, Fit loss U = -346.177, Fit loss F = 24.623, KL loss = 23703.803
# Epoch:  2201/25000, lambda1_mu = -0.301, lambda2_mu = 0.078, lambda1_std = 0.195, lambda2_std = 0.073
# Epoch:  2201/25000, error_25 = 0.99196, error_train = 0.99546
#
# Epoch:  2301/25000, total loss = 0.448, Fit loss U = -319.089, Fit loss F = 33.852, KL loss = 23633.164
# Epoch:  2301/25000, lambda1_mu = -0.290, lambda2_mu = 0.068, lambda1_std = 0.180, lambda2_std = 0.070
# Epoch:  2301/25000, error_25 = 0.99488, error_train = 1.00317
#
# Epoch:  2401/25000, total loss = 0.421, Fit loss U = -359.396, Fit loss F = 23.635, KL loss = 23567.715
# Epoch:  2401/25000, lambda1_mu = -0.299, lambda2_mu = 0.059, lambda1_std = 0.167, lambda2_std = 0.067
# Epoch:  2401/25000, error_25 = 0.98675, error_train = 1.00157
#
# Epoch:  2501/25000, total loss = 0.383, Fit loss U = -456.240, Fit loss F = 46.877, KL loss = 23507.131
# Epoch:  2501/25000, lambda1_mu = -0.270, lambda2_mu = 0.052, lambda1_std = 0.157, lambda2_std = 0.064
# Epoch:  2501/25000, error_25 = 0.98216, error_train = 0.99137
#
# Epoch:  2601/25000, total loss = 0.369, Fit loss U = -466.456, Fit loss F = 32.400, KL loss = 23444.396
# Epoch:  2601/25000, lambda1_mu = -0.235, lambda2_mu = 0.046, lambda1_std = 0.146, lambda2_std = 0.062
# Epoch:  2601/25000, error_25 = 0.98151, error_train = 0.99619
#
# Epoch:  2701/25000, total loss = 0.347, Fit loss U = -500.312, Fit loss F = 24.562, KL loss = 23384.475
# Epoch:  2701/25000, lambda1_mu = -0.203, lambda2_mu = 0.040, lambda1_std = 0.137, lambda2_std = 0.060
# Epoch:  2701/25000, error_25 = 0.97709, error_train = 0.98877
#
# Epoch:  2801/25000, total loss = 0.322, Fit loss U = -543.451, Fit loss F = 20.040, KL loss = 23329.324
# Epoch:  2801/25000, lambda1_mu = -0.172, lambda2_mu = 0.036, lambda1_std = 0.129, lambda2_std = 0.058
# Epoch:  2801/25000, error_25 = 0.97310, error_train = 0.98263
#
# Epoch:  2901/25000, total loss = 0.332, Fit loss U = -532.396, Fit loss F = 33.269, KL loss = 23270.176
# Epoch:  2901/25000, lambda1_mu = -0.130, lambda2_mu = 0.032, lambda1_std = 0.121, lambda2_std = 0.058
# Epoch:  2901/25000, error_25 = 0.96882, error_train = 0.98153
#
# Epoch:  3001/25000, total loss = 0.317, Fit loss U = -560.869, Fit loss F = 34.760, KL loss = 23213.887
# Epoch:  3001/25000, lambda1_mu = -0.110, lambda2_mu = 0.029, lambda1_std = 0.115, lambda2_std = 0.057
# Epoch:  3001/25000, error_25 = 0.96637, error_train = 0.97854
#
# Epoch:  3101/25000, total loss = 0.279, Fit loss U = -630.675, Fit loss F = 30.206, KL loss = 23154.436
# Epoch:  3101/25000, lambda1_mu = -0.082, lambda2_mu = 0.026, lambda1_std = 0.109, lambda2_std = 0.056
# Epoch:  3101/25000, error_25 = 0.96330, error_train = 0.98162
#
# Epoch:  3201/25000, total loss = 0.311, Fit loss U = -551.765, Fit loss F = 18.824, KL loss = 23095.359
# Epoch:  3201/25000, lambda1_mu = -0.045, lambda2_mu = 0.024, lambda1_std = 0.103, lambda2_std = 0.054
# Epoch:  3201/25000, error_25 = 0.95852, error_train = 0.98504
#
# Epoch:  3301/25000, total loss = 0.280, Fit loss U = -629.619, Fit loss F = 37.428, KL loss = 23036.824
# Epoch:  3301/25000, lambda1_mu = -0.019, lambda2_mu = 0.022, lambda1_std = 0.098, lambda2_std = 0.053
# Epoch:  3301/25000, error_25 = 0.95677, error_train = 0.97653
#
# Epoch:  3401/25000, total loss = 0.242, Fit loss U = -691.390, Fit loss F = 26.300, KL loss = 22981.672
# Epoch:  3401/25000, lambda1_mu = 0.015, lambda2_mu = 0.020, lambda1_std = 0.093, lambda2_std = 0.052
# Epoch:  3401/25000, error_25 = 0.94005, error_train = 0.96670
#
# Epoch:  3501/25000, total loss = 0.252, Fit loss U = -675.234, Fit loss F = 32.146, KL loss = 22926.090
# Epoch:  3501/25000, lambda1_mu = 0.041, lambda2_mu = 0.018, lambda1_std = 0.089, lambda2_std = 0.051
# Epoch:  3501/25000, error_25 = 0.93519, error_train = 0.95550
#
# Epoch:  3601/25000, total loss = 0.198, Fit loss U = -774.721, Fit loss F = 27.770, KL loss = 22874.635
# Epoch:  3601/25000, lambda1_mu = 0.085, lambda2_mu = 0.016, lambda1_std = 0.085, lambda2_std = 0.050
# Epoch:  3601/25000, error_25 = 0.91782, error_train = 0.95037
#
# Epoch:  3701/25000, total loss = 0.230, Fit loss U = -734.673, Fit loss F = 53.392, KL loss = 22828.428
# Epoch:  3701/25000, lambda1_mu = 0.123, lambda2_mu = 0.015, lambda1_std = 0.081, lambda2_std = 0.049
# Epoch:  3701/25000, error_25 = 0.90326, error_train = 0.94060
#
# Epoch:  3801/25000, total loss = 0.168, Fit loss U = -843.009, Fit loss F = 39.274, KL loss = 22781.805
# Epoch:  3801/25000, lambda1_mu = 0.182, lambda2_mu = 0.013, lambda1_std = 0.078, lambda2_std = 0.049
# Epoch:  3801/25000, error_25 = 0.88603, error_train = 0.92919
#
# Epoch:  3901/25000, total loss = 0.150, Fit loss U = -880.586, Fit loss F = 44.455, KL loss = 22736.609
# Epoch:  3901/25000, lambda1_mu = 0.213, lambda2_mu = 0.012, lambda1_std = 0.075, lambda2_std = 0.048
# Epoch:  3901/25000, error_25 = 0.86737, error_train = 0.91465
#
# Epoch:  4001/25000, total loss = 0.161, Fit loss U = -836.188, Fit loss F = 23.855, KL loss = 22695.920
# Epoch:  4001/25000, lambda1_mu = 0.258, lambda2_mu = 0.011, lambda1_std = 0.072, lambda2_std = 0.046
# Epoch:  4001/25000, error_25 = 0.84463, error_train = 0.89965
#
# Epoch:  4101/25000, total loss = 0.145, Fit loss U = -865.282, Fit loss F = 22.677, KL loss = 22658.627
# Epoch:  4101/25000, lambda1_mu = 0.276, lambda2_mu = 0.010, lambda1_std = 0.069, lambda2_std = 0.046
# Epoch:  4101/25000, error_25 = 0.84143, error_train = 0.89328
#
# Epoch:  4201/25000, total loss = 0.122, Fit loss U = -919.153, Fit loss F = 32.081, KL loss = 22618.951
# Epoch:  4201/25000, lambda1_mu = 0.278, lambda2_mu = 0.010, lambda1_std = 0.066, lambda2_std = 0.045
# Epoch:  4201/25000, error_25 = 0.81998, error_train = 0.88086
#
# Epoch:  4301/25000, total loss = 0.146, Fit loss U = -871.438, Fit loss F = 34.391, KL loss = 22580.863
# Epoch:  4301/25000, lambda1_mu = 0.283, lambda2_mu = 0.009, lambda1_std = 0.064, lambda2_std = 0.045
# Epoch:  4301/25000, error_25 = 0.80601, error_train = 0.87234
#
# Epoch:  4401/25000, total loss = 0.119, Fit loss U = -925.688, Fit loss F = 36.858, KL loss = 22540.646
# Epoch:  4401/25000, lambda1_mu = 0.282, lambda2_mu = 0.009, lambda1_std = 0.061, lambda2_std = 0.044
# Epoch:  4401/25000, error_25 = 0.79509, error_train = 0.86900
#
# Epoch:  4501/25000, total loss = 0.125, Fit loss U = -897.071, Fit loss F = 23.174, KL loss = 22495.053
# Epoch:  4501/25000, lambda1_mu = 0.288, lambda2_mu = 0.008, lambda1_std = 0.059, lambda2_std = 0.043
# Epoch:  4501/25000, error_25 = 0.78336, error_train = 0.85983
#
# Epoch:  4601/25000, total loss = 0.135, Fit loss U = -874.549, Fit loss F = 21.385, KL loss = 22451.412
# Epoch:  4601/25000, lambda1_mu = 0.270, lambda2_mu = 0.008, lambda1_std = 0.057, lambda2_std = 0.043
# Epoch:  4601/25000, error_25 = 0.76504, error_train = 0.85522
#
# Epoch:  4701/25000, total loss = 0.176, Fit loss U = -800.945, Fit loss F = 32.094, KL loss = 22408.717
# Epoch:  4701/25000, lambda1_mu = 0.266, lambda2_mu = 0.008, lambda1_std = 0.055, lambda2_std = 0.043
# Epoch:  4701/25000, error_25 = 0.75412, error_train = 0.84570
#
# Epoch:  4801/25000, total loss = 0.054, Fit loss U = -1025.651, Fit loss F = 15.991, KL loss = 22366.701
# Epoch:  4801/25000, lambda1_mu = 0.247, lambda2_mu = 0.008, lambda1_std = 0.053, lambda2_std = 0.043
# Epoch:  4801/25000, error_25 = 0.75704, error_train = 0.84277
#
# Epoch:  4901/25000, total loss = 0.122, Fit loss U = -895.773, Fit loss F = 22.932, KL loss = 22321.756
# Epoch:  4901/25000, lambda1_mu = 0.232, lambda2_mu = 0.008, lambda1_std = 0.051, lambda2_std = 0.042
# Epoch:  4901/25000, error_25 = 0.72931, error_train = 0.83278
#
# Epoch:  5001/25000, total loss = 0.089, Fit loss U = -954.552, Fit loss F = 19.068, KL loss = 22278.348
# Epoch:  5001/25000, lambda1_mu = 0.229, lambda2_mu = 0.008, lambda1_std = 0.049, lambda2_std = 0.042
# Epoch:  5001/25000, error_25 = 0.72742, error_train = 0.82295
#
# Epoch:  5101/25000, total loss = 0.055, Fit loss U = -1019.011, Fit loss F = 16.598, KL loss = 22236.115
# Epoch:  5101/25000, lambda1_mu = 0.213, lambda2_mu = 0.008, lambda1_std = 0.047, lambda2_std = 0.042
# Epoch:  5101/25000, error_25 = 0.69173, error_train = 0.81017
#
# Epoch:  5201/25000, total loss = 0.026, Fit loss U = -1089.209, Fit loss F = 30.591, KL loss = 22196.738
# Epoch:  5201/25000, lambda1_mu = 0.181, lambda2_mu = 0.008, lambda1_std = 0.045, lambda2_std = 0.041
# Epoch:  5201/25000, error_25 = 0.66987, error_train = 0.79902
#
# Epoch:  5301/25000, total loss = 0.067, Fit loss U = -996.975, Fit loss F = 22.901, KL loss = 22163.064
# Epoch:  5301/25000, lambda1_mu = 0.145, lambda2_mu = 0.007, lambda1_std = 0.043, lambda2_std = 0.041
# Epoch:  5301/25000, error_25 = 0.62750, error_train = 0.78109
#
# Epoch:  5401/25000, total loss = 0.028, Fit loss U = -1074.138, Fit loss F = 22.956, KL loss = 22136.312
# Epoch:  5401/25000, lambda1_mu = 0.123, lambda2_mu = 0.007, lambda1_std = 0.040, lambda2_std = 0.041
# Epoch:  5401/25000, error_25 = 0.58108, error_train = 0.75804
#
# Epoch:  5501/25000, total loss = 0.008, Fit loss U = -1117.264, Fit loss F = 27.367, KL loss = 22111.375
# Epoch:  5501/25000, lambda1_mu = 0.108, lambda2_mu = 0.007, lambda1_std = 0.038, lambda2_std = 0.040
# Epoch:  5501/25000, error_25 = 0.57253, error_train = 0.74504
#
# Epoch:  5601/25000, total loss = -0.016, Fit loss U = -1166.735, Fit loss F = 30.368, KL loss = 22091.781
# Epoch:  5601/25000, lambda1_mu = 0.087, lambda2_mu = 0.006, lambda1_std = 0.035, lambda2_std = 0.040
# Epoch:  5601/25000, error_25 = 0.56894, error_train = 0.73307
#
# Epoch:  5701/25000, total loss = 0.019, Fit loss U = -1094.028, Fit loss F = 27.784, KL loss = 22072.979
# Epoch:  5701/25000, lambda1_mu = 0.078, lambda2_mu = 0.005, lambda1_std = 0.033, lambda2_std = 0.039
# Epoch:  5701/25000, error_25 = 0.52652, error_train = 0.70846
#
# Epoch:  5801/25000, total loss = -0.074, Fit loss U = -1286.556, Fit loss F = 35.326, KL loss = 22056.234
# Epoch:  5801/25000, lambda1_mu = 0.076, lambda2_mu = 0.005, lambda1_std = 0.031, lambda2_std = 0.039
# Epoch:  5801/25000, error_25 = 0.51106, error_train = 0.71761
#
# Epoch:  5901/25000, total loss = -0.080, Fit loss U = -1287.418, Fit loss F = 25.844, KL loss = 22035.869
# Epoch:  5901/25000, lambda1_mu = 0.055, lambda2_mu = 0.004, lambda1_std = 0.030, lambda2_std = 0.038
# Epoch:  5901/25000, error_25 = 0.55242, error_train = 0.71634
#
# Epoch:  6001/25000, total loss = -0.079, Fit loss U = -1295.581, Fit loss F = 36.380, KL loss = 22015.389
# Epoch:  6001/25000, lambda1_mu = 0.046, lambda2_mu = 0.004, lambda1_std = 0.028, lambda2_std = 0.038
# Epoch:  6001/25000, error_25 = 0.48541, error_train = 0.69750
#
# Epoch:  6101/25000, total loss = -0.119, Fit loss U = -1361.346, Fit loss F = 23.194, KL loss = 21995.783
# Epoch:  6101/25000, lambda1_mu = 0.032, lambda2_mu = 0.003, lambda1_std = 0.027, lambda2_std = 0.038
# Epoch:  6101/25000, error_25 = 0.51011, error_train = 0.69943
#
# Epoch:  6201/25000, total loss = -0.079, Fit loss U = -1284.372, Fit loss F = 28.127, KL loss = 21974.371
# Epoch:  6201/25000, lambda1_mu = 0.015, lambda2_mu = 0.003, lambda1_std = 0.026, lambda2_std = 0.037
# Epoch:  6201/25000, error_25 = 0.45752, error_train = 0.69120
#
# Epoch:  6301/25000, total loss = -0.131, Fit loss U = -1386.455, Fit loss F = 26.427, KL loss = 21952.285
# Epoch:  6301/25000, lambda1_mu = 0.006, lambda2_mu = 0.003, lambda1_std = 0.024, lambda2_std = 0.037
# Epoch:  6301/25000, error_25 = 0.45650, error_train = 0.69720
#
# Epoch:  6401/25000, total loss = -0.174, Fit loss U = -1476.281, Fit loss F = 31.257, KL loss = 21928.248
# Epoch:  6401/25000, lambda1_mu = -0.001, lambda2_mu = 0.003, lambda1_std = 0.023, lambda2_std = 0.037
# Epoch:  6401/25000, error_25 = 0.43799, error_train = 0.68272
#
# Epoch:  6501/25000, total loss = -0.182, Fit loss U = -1482.444, Fit loss F = 22.374, KL loss = 21905.844
# Epoch:  6501/25000, lambda1_mu = -0.003, lambda2_mu = 0.002, lambda1_std = 0.022, lambda2_std = 0.036
# Epoch:  6501/25000, error_25 = 0.44134, error_train = 0.68258
#
# Epoch:  6601/25000, total loss = -0.194, Fit loss U = -1515.055, Fit loss F = 33.933, KL loss = 21877.982
# Epoch:  6601/25000, lambda1_mu = -0.017, lambda2_mu = 0.002, lambda1_std = 0.021, lambda2_std = 0.036
# Epoch:  6601/25000, error_25 = 0.42642, error_train = 0.68191
#
# Epoch:  6701/25000, total loss = -0.200, Fit loss U = -1520.462, Fit loss F = 28.374, KL loss = 21849.844
# Epoch:  6701/25000, lambda1_mu = -0.019, lambda2_mu = 0.002, lambda1_std = 0.021, lambda2_std = 0.035
# Epoch:  6701/25000, error_25 = 0.42043, error_train = 0.68965
#
# Epoch:  6801/25000, total loss = -0.177, Fit loss U = -1482.080, Fit loss F = 36.972, KL loss = 21823.230
# Epoch:  6801/25000, lambda1_mu = -0.021, lambda2_mu = 0.002, lambda1_std = 0.020, lambda2_std = 0.035
# Epoch:  6801/25000, error_25 = 0.42624, error_train = 0.68108
#
# Epoch:  6901/25000, total loss = -0.254, Fit loss U = -1638.639, Fit loss F = 40.849, KL loss = 21796.676
# Epoch:  6901/25000, lambda1_mu = -0.019, lambda2_mu = 0.002, lambda1_std = 0.019, lambda2_std = 0.035
# Epoch:  6901/25000, error_25 = 0.40920, error_train = 0.67173
#
# Epoch:  7001/25000, total loss = -0.228, Fit loss U = -1586.555, Fit loss F = 41.552, KL loss = 21773.824
# Epoch:  7001/25000, lambda1_mu = -0.012, lambda2_mu = 0.001, lambda1_std = 0.018, lambda2_std = 0.035
# Epoch:  7001/25000, error_25 = 0.39496, error_train = 0.66747
#
# Epoch:  7101/25000, total loss = -0.264, Fit loss U = -1660.927, Fit loss F = 46.049, KL loss = 21752.721
# Epoch:  7101/25000, lambda1_mu = -0.010, lambda2_mu = 0.001, lambda1_std = 0.018, lambda2_std = 0.035
# Epoch:  7101/25000, error_25 = 0.37626, error_train = 0.66563
#
# Epoch:  7201/25000, total loss = -0.245, Fit loss U = -1629.455, Fit loss F = 52.492, KL loss = 21731.783
# Epoch:  7201/25000, lambda1_mu = -0.005, lambda2_mu = 0.001, lambda1_std = 0.017, lambda2_std = 0.035
# Epoch:  7201/25000, error_25 = 0.38777, error_train = 0.65381
#
# Epoch:  7301/25000, total loss = -0.309, Fit loss U = -1752.514, Fit loss F = 48.569, KL loss = 21714.035
# Epoch:  7301/25000, lambda1_mu = 0.004, lambda2_mu = 0.001, lambda1_std = 0.016, lambda2_std = 0.035
# Epoch:  7301/25000, error_25 = 0.36508, error_train = 0.65734
#
# Epoch:  7401/25000, total loss = -0.296, Fit loss U = -1747.390, Fit loss F = 69.965, KL loss = 21701.518
# Epoch:  7401/25000, lambda1_mu = 0.006, lambda2_mu = 0.001, lambda1_std = 0.016, lambda2_std = 0.035
# Epoch:  7401/25000, error_25 = 0.33687, error_train = 0.66121
#
# Epoch:  7501/25000, total loss = -0.295, Fit loss U = -1763.317, Fit loss F = 87.622, KL loss = 21702.588
# Epoch:  7501/25000, lambda1_mu = -0.008, lambda2_mu = 0.001, lambda1_std = 0.015, lambda2_std = 0.034
# Epoch:  7501/25000, error_25 = 0.30744, error_train = 0.63614
#
# Epoch:  7601/25000, total loss = -0.323, Fit loss U = -1829.245, Fit loss F = 98.403, KL loss = 21712.340
# Epoch:  7601/25000, lambda1_mu = -0.028, lambda2_mu = 0.001, lambda1_std = 0.014, lambda2_std = 0.034
# Epoch:  7601/25000, error_25 = 0.28306, error_train = 0.64212
#
# Epoch:  7701/25000, total loss = -0.392, Fit loss U = -1970.773, Fit loss F = 101.068, KL loss = 21725.648
# Epoch:  7701/25000, lambda1_mu = -0.041, lambda2_mu = 0.001, lambda1_std = 0.013, lambda2_std = 0.034
# Epoch:  7701/25000, error_25 = 0.26031, error_train = 0.64663
#
# Epoch:  7801/25000, total loss = -0.463, Fit loss U = -2113.831, Fit loss F = 101.460, KL loss = 21738.799
# Epoch:  7801/25000, lambda1_mu = -0.038, lambda2_mu = 0.001, lambda1_std = 0.013, lambda2_std = 0.034
# Epoch:  7801/25000, error_25 = 0.26395, error_train = 0.63182
#
# Epoch:  7901/25000, total loss = -0.463, Fit loss U = -2160.405, Fit loss F = 146.088, KL loss = 21753.088
# Epoch:  7901/25000, lambda1_mu = -0.038, lambda2_mu = 0.001, lambda1_std = 0.012, lambda2_std = 0.034
# Epoch:  7901/25000, error_25 = 0.24087, error_train = 0.63427
#
# Epoch:  8001/25000, total loss = -0.488, Fit loss U = -2205.191, Fit loss F = 140.995, KL loss = 21766.904
# Epoch:  8001/25000, lambda1_mu = -0.030, lambda2_mu = 0.001, lambda1_std = 0.011, lambda2_std = 0.034
# Epoch:  8001/25000, error_25 = 0.23988, error_train = 0.62537
#
# Epoch:  8101/25000, total loss = -0.524, Fit loss U = -2266.710, Fit loss F = 129.321, KL loss = 21781.438
# Epoch:  8101/25000, lambda1_mu = -0.021, lambda2_mu = 0.001, lambda1_std = 0.011, lambda2_std = 0.033
# Epoch:  8101/25000, error_25 = 0.23890, error_train = 0.63463
#
# Epoch:  8201/25000, total loss = -0.493, Fit loss U = -2220.595, Fit loss F = 144.310, KL loss = 21794.061
# Epoch:  8201/25000, lambda1_mu = -0.006, lambda2_mu = 0.001, lambda1_std = 0.011, lambda2_std = 0.033
# Epoch:  8201/25000, error_25 = 0.23492, error_train = 0.62293
#
# Epoch:  8301/25000, total loss = -0.559, Fit loss U = -2353.226, Fit loss F = 145.851, KL loss = 21807.410
# Epoch:  8301/25000, lambda1_mu = -0.004, lambda2_mu = 0.001, lambda1_std = 0.010, lambda2_std = 0.033
# Epoch:  8301/25000, error_25 = 0.21201, error_train = 0.61307
#
# Epoch:  8401/25000, total loss = -0.548, Fit loss U = -2332.908, Fit loss F = 146.339, KL loss = 21820.457
# Epoch:  8401/25000, lambda1_mu = 0.011, lambda2_mu = 0.000, lambda1_std = 0.010, lambda2_std = 0.033
# Epoch:  8401/25000, error_25 = 0.21527, error_train = 0.62018
#
# Epoch:  8501/25000, total loss = -0.631, Fit loss U = -2511.742, Fit loss F = 157.401, KL loss = 21833.807
# Epoch:  8501/25000, lambda1_mu = 0.027, lambda2_mu = 0.000, lambda1_std = 0.009, lambda2_std = 0.033
# Epoch:  8501/25000, error_25 = 0.20553, error_train = 0.61258
#
# Epoch:  8601/25000, total loss = -0.612, Fit loss U = -2451.902, Fit loss F = 135.043, KL loss = 21847.656
# Epoch:  8601/25000, lambda1_mu = 0.037, lambda2_mu = 0.000, lambda1_std = 0.009, lambda2_std = 0.033
# Epoch:  8601/25000, error_25 = 0.21214, error_train = 0.62091
#
# Epoch:  8701/25000, total loss = -0.671, Fit loss U = -2580.960, Fit loss F = 145.932, KL loss = 21862.254
# Epoch:  8701/25000, lambda1_mu = 0.062, lambda2_mu = 0.000, lambda1_std = 0.009, lambda2_std = 0.032
# Epoch:  8701/25000, error_25 = 0.19995, error_train = 0.60711
#
# Epoch:  8801/25000, total loss = -0.658, Fit loss U = -2532.007, Fit loss F = 122.732, KL loss = 21876.199
# Epoch:  8801/25000, lambda1_mu = 0.073, lambda2_mu = 0.000, lambda1_std = 0.009, lambda2_std = 0.032
# Epoch:  8801/25000, error_25 = 0.19746, error_train = 0.60007
#
# Epoch:  8901/25000, total loss = -0.636, Fit loss U = -2517.969, Fit loss F = 152.121, KL loss = 21890.395
# Epoch:  8901/25000, lambda1_mu = 0.086, lambda2_mu = 0.000, lambda1_std = 0.008, lambda2_std = 0.032
# Epoch:  8901/25000, error_25 = 0.19187, error_train = 0.59910
#
# Epoch:  9001/25000, total loss = -0.723, Fit loss U = -2672.045, Fit loss F = 130.179, KL loss = 21903.660
# Epoch:  9001/25000, lambda1_mu = 0.092, lambda2_mu = 0.000, lambda1_std = 0.008, lambda2_std = 0.032
# Epoch:  9001/25000, error_25 = 0.19805, error_train = 0.60347
#
# Epoch:  9101/25000, total loss = -0.694, Fit loss U = -2628.616, Fit loss F = 144.340, KL loss = 21917.104
# Epoch:  9101/25000, lambda1_mu = 0.096, lambda2_mu = 0.000, lambda1_std = 0.008, lambda2_std = 0.032
# Epoch:  9101/25000, error_25 = 0.18740, error_train = 0.59865
#
# Epoch:  9201/25000, total loss = -0.740, Fit loss U = -2728.024, Fit loss F = 152.152, KL loss = 21927.963
# Epoch:  9201/25000, lambda1_mu = 0.109, lambda2_mu = 0.000, lambda1_std = 0.007, lambda2_std = 0.031
# Epoch:  9201/25000, error_25 = 0.18703, error_train = 0.59892
#
# Epoch:  9301/25000, total loss = -0.735, Fit loss U = -2743.333, Fit loss F = 177.335, KL loss = 21938.602
# Epoch:  9301/25000, lambda1_mu = 0.114, lambda2_mu = 0.000, lambda1_std = 0.007, lambda2_std = 0.031
# Epoch:  9301/25000, error_25 = 0.18704, error_train = 0.59845
#
# Epoch:  9401/25000, total loss = -0.741, Fit loss U = -2745.617, Fit loss F = 165.860, KL loss = 21950.127
# Epoch:  9401/25000, lambda1_mu = 0.122, lambda2_mu = 0.000, lambda1_std = 0.007, lambda2_std = 0.031
# Epoch:  9401/25000, error_25 = 0.18544, error_train = 0.59269
#
# Epoch:  9501/25000, total loss = -0.780, Fit loss U = -2827.574, Fit loss F = 169.693, KL loss = 21956.244
# Epoch:  9501/25000, lambda1_mu = 0.126, lambda2_mu = 0.000, lambda1_std = 0.007, lambda2_std = 0.031
# Epoch:  9501/25000, error_25 = 0.18171, error_train = 0.59522
#
# Epoch:  9601/25000, total loss = -0.797, Fit loss U = -2867.139, Fit loss F = 175.904, KL loss = 21962.598
# Epoch:  9601/25000, lambda1_mu = 0.135, lambda2_mu = 0.000, lambda1_std = 0.007, lambda2_std = 0.032
# Epoch:  9601/25000, error_25 = 0.17857, error_train = 0.58996
#
# Epoch:  9701/25000, total loss = -0.830, Fit loss U = -2938.263, Fit loss F = 179.131, KL loss = 21969.385
# Epoch:  9701/25000, lambda1_mu = 0.138, lambda2_mu = 0.000, lambda1_std = 0.006, lambda2_std = 0.031
# Epoch:  9701/25000, error_25 = 0.17379, error_train = 0.58982
#
# Epoch:  9801/25000, total loss = -0.800, Fit loss U = -2883.634, Fit loss F = 184.911, KL loss = 21973.305
# Epoch:  9801/25000, lambda1_mu = 0.141, lambda2_mu = 0.000, lambda1_std = 0.006, lambda2_std = 0.031
# Epoch:  9801/25000, error_25 = 0.18089, error_train = 0.57887
#
# Epoch:  9901/25000, total loss = -0.827, Fit loss U = -2924.743, Fit loss F = 172.636, KL loss = 21977.582
# Epoch:  9901/25000, lambda1_mu = 0.147, lambda2_mu = 0.000, lambda1_std = 0.006, lambda2_std = 0.032
# Epoch:  9901/25000, error_25 = 0.18507, error_train = 0.59201
#
# Epoch: 10001/25000, total loss = -0.768, Fit loss U = -2829.222, Fit loss F = 195.206, KL loss = 21979.803
# Epoch: 10001/25000, lambda1_mu = 0.154, lambda2_mu = 0.000, lambda1_std = 0.006, lambda2_std = 0.032
# Epoch: 10001/25000, error_25 = 0.17297, error_train = 0.58349
#
# Epoch: 10101/25000, total loss = -0.843, Fit loss U = -2956.625, Fit loss F = 172.445, KL loss = 21980.018
# Epoch: 10101/25000, lambda1_mu = 0.160, lambda2_mu = 0.000, lambda1_std = 0.006, lambda2_std = 0.032
# Epoch: 10101/25000, error_25 = 0.16946, error_train = 0.58404
#
# Epoch: 10201/25000, total loss = -0.877, Fit loss U = -3005.438, Fit loss F = 153.233, KL loss = 21979.379
# Epoch: 10201/25000, lambda1_mu = 0.162, lambda2_mu = 0.000, lambda1_std = 0.006, lambda2_std = 0.032
# Epoch: 10201/25000, error_25 = 0.16705, error_train = 0.57853
#
# Epoch: 10301/25000, total loss = -0.763, Fit loss U = -2807.050, Fit loss F = 181.502, KL loss = 21977.330
# Epoch: 10301/25000, lambda1_mu = 0.169, lambda2_mu = 0.000, lambda1_std = 0.006, lambda2_std = 0.033
# Epoch: 10301/25000, error_25 = 0.16622, error_train = 0.58074
#
# Epoch: 10401/25000, total loss = -0.945, Fit loss U = -3162.619, Fit loss F = 173.069, KL loss = 21978.482
# Epoch: 10401/25000, lambda1_mu = 0.168, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.033
# Epoch: 10401/25000, error_25 = 0.17125, error_train = 0.58957
#
# Epoch: 10501/25000, total loss = -0.911, Fit loss U = -3115.290, Fit loss F = 194.710, KL loss = 21978.578
# Epoch: 10501/25000, lambda1_mu = 0.172, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.034
# Epoch: 10501/25000, error_25 = 0.16601, error_train = 0.57309
#
# Epoch: 10601/25000, total loss = -0.942, Fit loss U = -3165.071, Fit loss F = 182.079, KL loss = 21978.918
# Epoch: 10601/25000, lambda1_mu = 0.176, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.034
# Epoch: 10601/25000, error_25 = 0.16880, error_train = 0.58410
#
# Epoch: 10701/25000, total loss = -0.949, Fit loss U = -3192.594, Fit loss F = 195.440, KL loss = 21975.213
# Epoch: 10701/25000, lambda1_mu = 0.184, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.034
# Epoch: 10701/25000, error_25 = 0.16173, error_train = 0.58309
#
# Epoch: 10801/25000, total loss = -0.932, Fit loss U = -3172.134, Fit loss F = 208.395, KL loss = 21976.346
# Epoch: 10801/25000, lambda1_mu = 0.187, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.035
# Epoch: 10801/25000, error_25 = 0.16389, error_train = 0.57248
#
# Epoch: 10901/25000, total loss = -0.972, Fit loss U = -3248.931, Fit loss F = 205.893, KL loss = 21971.018
# Epoch: 10901/25000, lambda1_mu = 0.189, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.035
# Epoch: 10901/25000, error_25 = 0.15939, error_train = 0.57110
#
# Epoch: 11001/25000, total loss = -0.980, Fit loss U = -3261.671, Fit loss F = 203.972, KL loss = 21970.006
# Epoch: 11001/25000, lambda1_mu = 0.197, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.036
# Epoch: 11001/25000, error_25 = 0.15594, error_train = 0.57791
#
# Epoch: 11101/25000, total loss = -0.996, Fit loss U = -3290.569, Fit loss F = 199.376, KL loss = 21968.887
# Epoch: 11101/25000, lambda1_mu = 0.198, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.036
# Epoch: 11101/25000, error_25 = 0.15667, error_train = 0.57507
#
# Epoch: 11201/25000, total loss = -0.979, Fit loss U = -3258.819, Fit loss F = 201.900, KL loss = 21966.562
# Epoch: 11201/25000, lambda1_mu = 0.204, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.037
# Epoch: 11201/25000, error_25 = 0.15141, error_train = 0.56631
#
# Epoch: 11301/25000, total loss = -1.049, Fit loss U = -3399.739, Fit loss F = 203.926, KL loss = 21960.135
# Epoch: 11301/25000, lambda1_mu = 0.205, lambda2_mu = 0.000, lambda1_std = 0.005, lambda2_std = 0.037
# Epoch: 11301/25000, error_25 = 0.15003, error_train = 0.57129
#
# Epoch: 11401/25000, total loss = -0.992, Fit loss U = -3294.309, Fit loss F = 211.977, KL loss = 21959.160
# Epoch: 11401/25000, lambda1_mu = 0.208, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.037
# Epoch: 11401/25000, error_25 = 0.15306, error_train = 0.56441
#
# Epoch: 11501/25000, total loss = -1.063, Fit loss U = -3426.413, Fit loss F = 202.421, KL loss = 21954.971
# Epoch: 11501/25000, lambda1_mu = 0.215, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.038
# Epoch: 11501/25000, error_25 = 0.15162, error_train = 0.57071
#
# Epoch: 11601/25000, total loss = -1.060, Fit loss U = -3425.086, Fit loss F = 208.034, KL loss = 21949.857
# Epoch: 11601/25000, lambda1_mu = 0.219, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.039
# Epoch: 11601/25000, error_25 = 0.15322, error_train = 0.56937
#
# Epoch: 11701/25000, total loss = -1.056, Fit loss U = -3407.084, Fit loss F = 198.404, KL loss = 21945.344
# Epoch: 11701/25000, lambda1_mu = 0.218, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.040
# Epoch: 11701/25000, error_25 = 0.15345, error_train = 0.57121
#
# Epoch: 11801/25000, total loss = -1.059, Fit loss U = -3430.195, Fit loss F = 214.699, KL loss = 21944.738
# Epoch: 11801/25000, lambda1_mu = 0.221, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.041
# Epoch: 11801/25000, error_25 = 0.14983, error_train = 0.56971
#
# Epoch: 11901/25000, total loss = -1.107, Fit loss U = -3537.857, Fit loss F = 227.511, KL loss = 21941.043
# Epoch: 11901/25000, lambda1_mu = 0.225, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.042
# Epoch: 11901/25000, error_25 = 0.15207, error_train = 0.57141
#
# Epoch: 12001/25000, total loss = -1.050, Fit loss U = -3420.006, Fit loss F = 223.291, KL loss = 21938.559
# Epoch: 12001/25000, lambda1_mu = 0.230, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.043
# Epoch: 12001/25000, error_25 = 0.14158, error_train = 0.56662
#
# Epoch: 12101/25000, total loss = -1.101, Fit loss U = -3530.737, Fit loss F = 232.297, KL loss = 21938.453
# Epoch: 12101/25000, lambda1_mu = 0.228, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.044
# Epoch: 12101/25000, error_25 = 0.14437, error_train = 0.56505
#
# Epoch: 12201/25000, total loss = -1.069, Fit loss U = -3459.653, Fit loss F = 224.243, KL loss = 21936.922
# Epoch: 12201/25000, lambda1_mu = 0.235, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.045
# Epoch: 12201/25000, error_25 = 0.14197, error_train = 0.56331
#
# Epoch: 12301/25000, total loss = -1.140, Fit loss U = -3600.180, Fit loss F = 223.023, KL loss = 21936.674
# Epoch: 12301/25000, lambda1_mu = 0.233, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.047
# Epoch: 12301/25000, error_25 = 0.13860, error_train = 0.56093
#
# Epoch: 12401/25000, total loss = -1.089, Fit loss U = -3515.264, Fit loss F = 241.134, KL loss = 21933.104
# Epoch: 12401/25000, lambda1_mu = 0.236, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.048
# Epoch: 12401/25000, error_25 = 0.14011, error_train = 0.56303
#
# Epoch: 12501/25000, total loss = -1.153, Fit loss U = -3658.709, Fit loss F = 255.985, KL loss = 21933.959
# Epoch: 12501/25000, lambda1_mu = 0.241, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.050
# Epoch: 12501/25000, error_25 = 0.13950, error_train = 0.55736
#
# Epoch: 12601/25000, total loss = -1.187, Fit loss U = -3726.484, Fit loss F = 256.292, KL loss = 21933.719
# Epoch: 12601/25000, lambda1_mu = 0.243, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.051
# Epoch: 12601/25000, error_25 = 0.14500, error_train = 0.56369
#
# Epoch: 12701/25000, total loss = -1.139, Fit loss U = -3627.920, Fit loss F = 252.751, KL loss = 21932.898
# Epoch: 12701/25000, lambda1_mu = 0.245, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.052
# Epoch: 12701/25000, error_25 = 0.13450, error_train = 0.56379
#
# Epoch: 12801/25000, total loss = -1.134, Fit loss U = -3607.719, Fit loss F = 243.971, KL loss = 21930.139
# Epoch: 12801/25000, lambda1_mu = 0.251, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.053
# Epoch: 12801/25000, error_25 = 0.13732, error_train = 0.56203
#
# Epoch: 12901/25000, total loss = -1.198, Fit loss U = -3734.318, Fit loss F = 242.260, KL loss = 21926.455
# Epoch: 12901/25000, lambda1_mu = 0.249, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.055
# Epoch: 12901/25000, error_25 = 0.13321, error_train = 0.55437
#
# Epoch: 13001/25000, total loss = -1.230, Fit loss U = -3793.370, Fit loss F = 236.083, KL loss = 21927.035
# Epoch: 13001/25000, lambda1_mu = 0.249, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.057
# Epoch: 13001/25000, error_25 = 0.13926, error_train = 0.56085
#
# Epoch: 13101/25000, total loss = -1.140, Fit loss U = -3635.593, Fit loss F = 259.828, KL loss = 21927.047
# Epoch: 13101/25000, lambda1_mu = 0.254, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.058
# Epoch: 13101/25000, error_25 = 0.13608, error_train = 0.56066
#
# Epoch: 13201/25000, total loss = -1.187, Fit loss U = -3736.569, Fit loss F = 266.792, KL loss = 21926.373
# Epoch: 13201/25000, lambda1_mu = 0.258, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.059
# Epoch: 13201/25000, error_25 = 0.13342, error_train = 0.55725
#
# Epoch: 13301/25000, total loss = -1.224, Fit loss U = -3808.687, Fit loss F = 264.571, KL loss = 21923.312
# Epoch: 13301/25000, lambda1_mu = 0.257, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.061
# Epoch: 13301/25000, error_25 = 0.13187, error_train = 0.55906
#
# Epoch: 13401/25000, total loss = -1.235, Fit loss U = -3832.547, Fit loss F = 266.810, KL loss = 21921.799
# Epoch: 13401/25000, lambda1_mu = 0.260, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.062
# Epoch: 13401/25000, error_25 = 0.13378, error_train = 0.55719
#
# Epoch: 13501/25000, total loss = -1.266, Fit loss U = -3887.753, Fit loss F = 259.456, KL loss = 21924.260
# Epoch: 13501/25000, lambda1_mu = 0.263, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.064
# Epoch: 13501/25000, error_25 = 0.13320, error_train = 0.55565
#
# Epoch: 13601/25000, total loss = -1.116, Fit loss U = -3606.223, Fit loss F = 277.708, KL loss = 21918.596
# Epoch: 13601/25000, lambda1_mu = 0.267, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.065
# Epoch: 13601/25000, error_25 = 0.13177, error_train = 0.55207
#
# Epoch: 13701/25000, total loss = -1.265, Fit loss U = -3907.745, Fit loss F = 281.239, KL loss = 21918.432
# Epoch: 13701/25000, lambda1_mu = 0.266, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.067
# Epoch: 13701/25000, error_25 = 0.13508, error_train = 0.55989
#
# Epoch: 13801/25000, total loss = -1.279, Fit loss U = -3929.872, Fit loss F = 276.711, KL loss = 21919.227
# Epoch: 13801/25000, lambda1_mu = 0.274, lambda2_mu = 0.000, lambda1_std = 0.004, lambda2_std = 0.068
# Epoch: 13801/25000, error_25 = 0.13248, error_train = 0.55358
#
# Epoch: 13901/25000, total loss = -1.261, Fit loss U = -3890.127, Fit loss F = 271.647, KL loss = 21919.857
# Epoch: 13901/25000, lambda1_mu = 0.269, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.068
# Epoch: 13901/25000, error_25 = 0.12810, error_train = 0.56004
#
# Epoch: 14001/25000, total loss = -1.225, Fit loss U = -3824.355, Fit loss F = 277.795, KL loss = 21916.549
# Epoch: 14001/25000, lambda1_mu = 0.276, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.069
# Epoch: 14001/25000, error_25 = 0.13186, error_train = 0.55264
#
# Epoch: 14101/25000, total loss = -1.271, Fit loss U = -3918.911, Fit loss F = 280.206, KL loss = 21916.641
# Epoch: 14101/25000, lambda1_mu = 0.274, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.070
# Epoch: 14101/25000, error_25 = 0.12472, error_train = 0.54999
#
# Epoch: 14201/25000, total loss = -1.310, Fit loss U = -3991.373, Fit loss F = 275.612, KL loss = 21916.520
# Epoch: 14201/25000, lambda1_mu = 0.280, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.072
# Epoch: 14201/25000, error_25 = 0.12358, error_train = 0.55413
#
# Epoch: 14301/25000, total loss = -1.293, Fit loss U = -3961.774, Fit loss F = 279.768, KL loss = 21909.590
# Epoch: 14301/25000, lambda1_mu = 0.274, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.073
# Epoch: 14301/25000, error_25 = 0.12640, error_train = 0.55426
#
# Epoch: 14401/25000, total loss = -1.338, Fit loss U = -4057.454, Fit loss F = 286.733, KL loss = 21906.467
# Epoch: 14401/25000, lambda1_mu = 0.283, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.074
# Epoch: 14401/25000, error_25 = 0.12694, error_train = 0.55624
#
# Epoch: 14501/25000, total loss = -1.307, Fit loss U = -3983.999, Fit loss F = 275.006, KL loss = 21906.357
# Epoch: 14501/25000, lambda1_mu = 0.278, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.076
# Epoch: 14501/25000, error_25 = 0.14397, error_train = 0.56042
#
# Epoch: 14601/25000, total loss = -1.330, Fit loss U = -4049.014, Fit loss F = 293.578, KL loss = 21901.648
# Epoch: 14601/25000, lambda1_mu = 0.279, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.077
# Epoch: 14601/25000, error_25 = 0.13131, error_train = 0.55260
#
# Epoch: 14701/25000, total loss = -1.352, Fit loss U = -4089.772, Fit loss F = 291.436, KL loss = 21897.996
# Epoch: 14701/25000, lambda1_mu = 0.284, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.078
# Epoch: 14701/25000, error_25 = 0.12744, error_train = 0.55896
#
# Epoch: 14801/25000, total loss = -1.323, Fit loss U = -4030.336, Fit loss F = 288.573, KL loss = 21896.420
# Epoch: 14801/25000, lambda1_mu = 0.282, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.080
# Epoch: 14801/25000, error_25 = 0.12656, error_train = 0.55751
#
# Epoch: 14901/25000, total loss = -1.300, Fit loss U = -3994.953, Fit loss F = 300.158, KL loss = 21893.324
# Epoch: 14901/25000, lambda1_mu = 0.283, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.082
# Epoch: 14901/25000, error_25 = 0.13133, error_train = 0.55709
#
# Epoch: 15001/25000, total loss = -1.351, Fit loss U = -4091.802, Fit loss F = 294.664, KL loss = 21890.443
# Epoch: 15001/25000, lambda1_mu = 0.286, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.083
# Epoch: 15001/25000, error_25 = 0.12684, error_train = 0.55380
#
# Epoch: 15101/25000, total loss = -1.361, Fit loss U = -4120.066, Fit loss F = 302.619, KL loss = 21890.848
# Epoch: 15101/25000, lambda1_mu = 0.288, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.085
# Epoch: 15101/25000, error_25 = 0.13417, error_train = 0.56139
#
# Epoch: 15201/25000, total loss = -1.381, Fit loss U = -4166.000, Fit loss F = 308.882, KL loss = 21889.961
# Epoch: 15201/25000, lambda1_mu = 0.288, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.086
# Epoch: 15201/25000, error_25 = 0.13547, error_train = 0.55221
#
# Epoch: 15301/25000, total loss = -1.285, Fit loss U = -3978.132, Fit loss F = 314.713, KL loss = 21886.482
# Epoch: 15301/25000, lambda1_mu = 0.292, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.087
# Epoch: 15301/25000, error_25 = 0.12622, error_train = 0.55190
#
# Epoch: 15401/25000, total loss = -1.264, Fit loss U = -3945.059, Fit loss F = 322.393, KL loss = 21882.260
# Epoch: 15401/25000, lambda1_mu = 0.289, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.090
# Epoch: 15401/25000, error_25 = 0.12788, error_train = 0.54899
#
# Epoch: 15501/25000, total loss = -1.427, Fit loss U = -4260.123, Fit loss F = 311.581, KL loss = 21879.547
# Epoch: 15501/25000, lambda1_mu = 0.296, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.091
# Epoch: 15501/25000, error_25 = 0.12595, error_train = 0.55205
#
# Epoch: 15601/25000, total loss = -1.402, Fit loss U = -4207.493, Fit loss F = 310.254, KL loss = 21879.348
# Epoch: 15601/25000, lambda1_mu = 0.294, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.091
# Epoch: 15601/25000, error_25 = 0.13045, error_train = 0.55539
#
# Epoch: 15701/25000, total loss = -1.447, Fit loss U = -4307.148, Fit loss F = 319.702, KL loss = 21878.793
# Epoch: 15701/25000, lambda1_mu = 0.294, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.092
# Epoch: 15701/25000, error_25 = 0.12700, error_train = 0.55202
#
# Epoch: 15801/25000, total loss = -1.407, Fit loss U = -4223.271, Fit loss F = 316.341, KL loss = 21874.688
# Epoch: 15801/25000, lambda1_mu = 0.293, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.093
# Epoch: 15801/25000, error_25 = 0.12740, error_train = 0.55139
#
# Epoch: 15901/25000, total loss = -1.425, Fit loss U = -4274.850, Fit loss F = 330.883, KL loss = 21873.328
# Epoch: 15901/25000, lambda1_mu = 0.297, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.094
# Epoch: 15901/25000, error_25 = 0.12556, error_train = 0.55403
#
# Epoch: 16001/25000, total loss = -1.331, Fit loss U = -4075.828, Fit loss F = 319.983, KL loss = 21870.545
# Epoch: 16001/25000, lambda1_mu = 0.299, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.096
# Epoch: 16001/25000, error_25 = 0.13100, error_train = 0.55347
#
# Epoch: 16101/25000, total loss = -1.415, Fit loss U = -4234.493, Fit loss F = 311.040, KL loss = 21868.725
# Epoch: 16101/25000, lambda1_mu = 0.299, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.097
# Epoch: 16101/25000, error_25 = 0.12472, error_train = 0.55354
#
# Epoch: 16201/25000, total loss = -1.455, Fit loss U = -4336.098, Fit loss F = 331.886, KL loss = 21865.279
# Epoch: 16201/25000, lambda1_mu = 0.302, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.098
# Epoch: 16201/25000, error_25 = 0.12784, error_train = 0.55045
#
# Epoch: 16301/25000, total loss = -1.469, Fit loss U = -4359.123, Fit loss F = 329.010, KL loss = 21862.113
# Epoch: 16301/25000, lambda1_mu = 0.302, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.098
# Epoch: 16301/25000, error_25 = 0.12857, error_train = 0.55122
#
# Epoch: 16401/25000, total loss = -1.431, Fit loss U = -4299.528, Fit loss F = 343.658, KL loss = 21861.602
# Epoch: 16401/25000, lambda1_mu = 0.301, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.099
# Epoch: 16401/25000, error_25 = 0.13448, error_train = 0.55284
#
# Epoch: 16501/25000, total loss = -1.490, Fit loss U = -4404.392, Fit loss F = 331.863, KL loss = 21864.371
# Epoch: 16501/25000, lambda1_mu = 0.305, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.098
# Epoch: 16501/25000, error_25 = 0.13110, error_train = 0.55336
#
# Epoch: 16601/25000, total loss = -1.502, Fit loss U = -4432.734, Fit loss F = 335.387, KL loss = 21865.324
# Epoch: 16601/25000, lambda1_mu = 0.306, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.097
# Epoch: 16601/25000, error_25 = 0.13322, error_train = 0.55720
#
# Epoch: 16701/25000, total loss = -1.473, Fit loss U = -4369.402, Fit loss F = 330.723, KL loss = 21865.258
# Epoch: 16701/25000, lambda1_mu = 0.308, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.098
# Epoch: 16701/25000, error_25 = 0.12514, error_train = 0.54777
#
# Epoch: 16801/25000, total loss = -1.466, Fit loss U = -4380.583, Fit loss F = 355.885, KL loss = 21862.469
# Epoch: 16801/25000, lambda1_mu = 0.310, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.097
# Epoch: 16801/25000, error_25 = 0.12564, error_train = 0.55033
#
# Epoch: 16901/25000, total loss = -1.507, Fit loss U = -4446.766, Fit loss F = 340.366, KL loss = 21861.135
# Epoch: 16901/25000, lambda1_mu = 0.310, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.095
# Epoch: 16901/25000, error_25 = 0.12800, error_train = 0.55463
#
# Epoch: 17001/25000, total loss = -1.516, Fit loss U = -4468.978, Fit loss F = 343.302, KL loss = 21862.670
# Epoch: 17001/25000, lambda1_mu = 0.309, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.094
# Epoch: 17001/25000, error_25 = 0.13144, error_train = 0.55028
#
# Epoch: 17101/25000, total loss = -1.516, Fit loss U = -4460.712, Fit loss F = 335.577, KL loss = 21864.715
# Epoch: 17101/25000, lambda1_mu = 0.314, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.093
# Epoch: 17101/25000, error_25 = 0.12909, error_train = 0.55296
#
# Epoch: 17201/25000, total loss = -1.485, Fit loss U = -4409.292, Fit loss F = 346.043, KL loss = 21864.475
# Epoch: 17201/25000, lambda1_mu = 0.312, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.093
# Epoch: 17201/25000, error_25 = 0.12482, error_train = 0.54843
#
# Epoch: 17301/25000, total loss = -1.545, Fit loss U = -4527.385, Fit loss F = 344.933, KL loss = 21865.340
# Epoch: 17301/25000, lambda1_mu = 0.316, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.093
# Epoch: 17301/25000, error_25 = 0.12083, error_train = 0.55027
#
# Epoch: 17401/25000, total loss = -1.475, Fit loss U = -4396.480, Fit loss F = 352.493, KL loss = 21862.154
# Epoch: 17401/25000, lambda1_mu = 0.312, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.092
# Epoch: 17401/25000, error_25 = 0.12917, error_train = 0.54865
#
# Epoch: 17501/25000, total loss = -1.488, Fit loss U = -4435.376, Fit loss F = 366.722, KL loss = 21864.812
# Epoch: 17501/25000, lambda1_mu = 0.318, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.092
# Epoch: 17501/25000, error_25 = 0.12815, error_train = 0.55382
#
# Epoch: 17601/25000, total loss = -1.541, Fit loss U = -4534.553, Fit loss F = 358.517, KL loss = 21866.320
# Epoch: 17601/25000, lambda1_mu = 0.316, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.090
# Epoch: 17601/25000, error_25 = 0.12531, error_train = 0.55198
#
# Epoch: 17701/25000, total loss = -1.544, Fit loss U = -4533.300, Fit loss F = 352.519, KL loss = 21867.422
# Epoch: 17701/25000, lambda1_mu = 0.319, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.089
# Epoch: 17701/25000, error_25 = 0.12396, error_train = 0.54774
#
# Epoch: 17801/25000, total loss = -1.523, Fit loss U = -4483.195, Fit loss F = 343.267, KL loss = 21864.396
# Epoch: 17801/25000, lambda1_mu = 0.320, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.087
# Epoch: 17801/25000, error_25 = 0.12272, error_train = 0.54385
#
# Epoch: 17901/25000, total loss = -1.542, Fit loss U = -4528.893, Fit loss F = 350.917, KL loss = 21862.904
# Epoch: 17901/25000, lambda1_mu = 0.319, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.085
# Epoch: 17901/25000, error_25 = 0.12726, error_train = 0.54973
#
# Epoch: 18001/25000, total loss = -1.568, Fit loss U = -4586.345, Fit loss F = 357.644, KL loss = 21862.273
# Epoch: 18001/25000, lambda1_mu = 0.316, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.085
# Epoch: 18001/25000, error_25 = 0.13109, error_train = 0.54985
#
# Epoch: 18101/25000, total loss = -1.561, Fit loss U = -4575.521, Fit loss F = 360.297, KL loss = 21860.230
# Epoch: 18101/25000, lambda1_mu = 0.322, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.084
# Epoch: 18101/25000, error_25 = 0.12453, error_train = 0.54697
#
# Epoch: 18201/25000, total loss = -1.563, Fit loss U = -4589.012, Fit loss F = 370.149, KL loss = 21862.672
# Epoch: 18201/25000, lambda1_mu = 0.325, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.083
# Epoch: 18201/25000, error_25 = 0.12164, error_train = 0.55315
#
# Epoch: 18301/25000, total loss = -1.532, Fit loss U = -4518.068, Fit loss F = 359.960, KL loss = 21863.629
# Epoch: 18301/25000, lambda1_mu = 0.320, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.081
# Epoch: 18301/25000, error_25 = 0.13277, error_train = 0.55312
#
# Epoch: 18401/25000, total loss = -1.571, Fit loss U = -4609.339, Fit loss F = 374.278, KL loss = 21863.779
# Epoch: 18401/25000, lambda1_mu = 0.322, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.079
# Epoch: 18401/25000, error_25 = 0.13073, error_train = 0.55668
#
# Epoch: 18501/25000, total loss = -1.548, Fit loss U = -4555.212, Fit loss F = 366.166, KL loss = 21861.027
# Epoch: 18501/25000, lambda1_mu = 0.326, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.078
# Epoch: 18501/25000, error_25 = 0.12573, error_train = 0.55230
#
# Epoch: 18601/25000, total loss = -1.563, Fit loss U = -4589.533, Fit loss F = 370.884, KL loss = 21859.621
# Epoch: 18601/25000, lambda1_mu = 0.327, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.077
# Epoch: 18601/25000, error_25 = 0.12296, error_train = 0.55095
#
# Epoch: 18701/25000, total loss = -1.582, Fit loss U = -4631.566, Fit loss F = 374.604, KL loss = 21855.174
# Epoch: 18701/25000, lambda1_mu = 0.329, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.076
# Epoch: 18701/25000, error_25 = 0.12664, error_train = 0.55231
#
# Epoch: 18801/25000, total loss = -1.647, Fit loss U = -4772.805, Fit loss F = 385.680, KL loss = 21854.416
# Epoch: 18801/25000, lambda1_mu = 0.326, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.074
# Epoch: 18801/25000, error_25 = 0.12397, error_train = 0.54849
#
# Epoch: 18901/25000, total loss = -1.523, Fit loss U = -4516.747, Fit loss F = 378.285, KL loss = 21853.619
# Epoch: 18901/25000, lambda1_mu = 0.325, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.074
# Epoch: 18901/25000, error_25 = 0.12367, error_train = 0.54921
#
# Epoch: 19001/25000, total loss = -1.533, Fit loss U = -4537.383, Fit loss F = 378.438, KL loss = 21851.609
# Epoch: 19001/25000, lambda1_mu = 0.326, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.074
# Epoch: 19001/25000, error_25 = 0.12681, error_train = 0.55091
#
# Epoch: 19101/25000, total loss = -1.570, Fit loss U = -4614.449, Fit loss F = 382.533, KL loss = 21851.244
# Epoch: 19101/25000, lambda1_mu = 0.328, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.073
# Epoch: 19101/25000, error_25 = 0.12196, error_train = 0.54722
#
# Epoch: 19201/25000, total loss = -1.630, Fit loss U = -4745.187, Fit loss F = 391.838, KL loss = 21847.234
# Epoch: 19201/25000, lambda1_mu = 0.331, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.072
# Epoch: 19201/25000, error_25 = 0.13266, error_train = 0.55226
#
# Epoch: 19301/25000, total loss = -1.530, Fit loss U = -4540.757, Fit loss F = 387.946, KL loss = 21848.184
# Epoch: 19301/25000, lambda1_mu = 0.327, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.070
# Epoch: 19301/25000, error_25 = 0.12204, error_train = 0.54864
#
# Epoch: 19401/25000, total loss = -1.551, Fit loss U = -4586.226, Fit loss F = 392.752, KL loss = 21846.061
# Epoch: 19401/25000, lambda1_mu = 0.332, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.069
# Epoch: 19401/25000, error_25 = 0.12378, error_train = 0.55027
#
# Epoch: 19501/25000, total loss = -1.627, Fit loss U = -4733.239, Fit loss F = 387.835, KL loss = 21842.846
# Epoch: 19501/25000, lambda1_mu = 0.332, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.069
# Epoch: 19501/25000, error_25 = 0.12486, error_train = 0.54900
#
# Epoch: 19601/25000, total loss = -1.647, Fit loss U = -4780.808, Fit loss F = 395.028, KL loss = 21842.959
# Epoch: 19601/25000, lambda1_mu = 0.331, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.069
# Epoch: 19601/25000, error_25 = 0.11787, error_train = 0.54564
#
# Epoch: 19701/25000, total loss = -1.632, Fit loss U = -4749.521, Fit loss F = 393.690, KL loss = 21840.535
# Epoch: 19701/25000, lambda1_mu = 0.334, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.068
# Epoch: 19701/25000, error_25 = 0.12586, error_train = 0.54983
#
# Epoch: 19801/25000, total loss = -1.678, Fit loss U = -4845.043, Fit loss F = 397.902, KL loss = 21841.219
# Epoch: 19801/25000, lambda1_mu = 0.333, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.067
# Epoch: 19801/25000, error_25 = 0.12483, error_train = 0.54757
#
# Epoch: 19901/25000, total loss = -1.671, Fit loss U = -4827.953, Fit loss F = 393.533, KL loss = 21838.170
# Epoch: 19901/25000, lambda1_mu = 0.333, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.067
# Epoch: 19901/25000, error_25 = 0.12452, error_train = 0.55076
#
# Epoch: 20001/25000, total loss = -1.662, Fit loss U = -4815.618, Fit loss F = 400.611, KL loss = 21835.865
# Epoch: 20001/25000, lambda1_mu = 0.332, lambda2_mu = 0.000, lambda1_std = 0.003, lambda2_std = 0.067
# Epoch: 20001/25000, error_25 = 0.12373, error_train = 0.54969
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 6
#       2 writer = SummaryWriter(comment = '_KdV')
#       4 for i in range(num_epochs):
# ----> 6     EU, EF, KL_loss, total_loss = net.fit(X, t, U, no_samples = 20)
#       8     fit_loss_U_train[i] = EU.item()
#       9     fit_loss_F_train[i] = EF.item()
#
# Cell In[29], line 99, in BBP_Model_PINN.fit(self, X, t, U, no_samples)
#      96 lambda1_sample = self.lambda1_mus + lambda1_epsilons * lambda1_stds
#      97 lambda2_sample = self.lambda2_mus + lambda2_epsilons * lambda2_stds
# ---> 99 u_pred, log_noise_u, KL_loss_para = self.net_U(X, t)
#     100 f_pred = self.net_F(X, t, lambda1_sample, lambda2_sample)
#     102 # calculate fit loss based on mean and standard deviation of output
#
# Cell In[29], line 46, in BBP_Model_PINN.net_U(self, x, t)
#      44 xt = torch.cat((x,t), dim=1)
#      45 xt = 2*(xt-self.xt_lb)/(self.xt_ub-self.xt_lb) - 1
# ---> 46 out, KL_loss = self.network(xt)
#      48 u = out[:,0:1]
#      49 log_noise_u = out[:,1:2]
#
# File ~/miniconda3/envs/torch_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/torch/Bayesian_DL/BPINN/model.py:88, in forward(self, x)
#      86 else:
#      87     output = torch.mm(x, self.weight_mus) + self.bias_mus
# ---> 88     return output
#
# File ~/miniconda3/envs/torch_env/lib/python3.8/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/torch/Bayesian_DL/BPINN/model.py:41, in BayesLinear_Normalq.forward(self, x, sample)
#      39 # computing the KL loss term
#      40 KL_loss_weight = get_kl_Gaussian_divergence(self.prior.mu, self.prior.sigma**2, self.weight_mus, weight_stds**2)
# ---> 41 KL_loss_bias = get_kl_Gaussian_divergence(self.prior.mu, self.prior.sigma**2, self.bias_mus, bias_stds**2)
#      42 KL_loss = KL_loss_weight + KL_loss_bias
#      44 return output, KL_loss
#
# File ~/torch/Bayesian_DL/BPINN/utils.py:34, in get_kl_Gaussian_divergence(prior_mus, prior_cov, varpost_mus, varpost_cov)
#      32 KL_loss = 0.5 * (torch.log(prior_cov / varpost_cov)).sum() - 0.5 * varpost_cov.numel()
#      33 KL_loss += 0.5 * (varpost_cov / prior_cov).sum()
# ---> 34 KL_loss +=  0.5 * ((varpost_mus - prior_mus) ** 2 / prior_cov).sum()
#      35 return KL_loss
#
# KeyboardInterrupt:

# %%
x = data['x'].flatten()[:,None]
X_u_test_25 = np.hstack([x, 0.25*np.ones_like((x))]); u_test_25 = Exact[50]; u_mean_25 = Exact_[50]
X_u_test_50 = np.hstack([x, 0.50*np.ones_like((x))]); u_test_50 = Exact[100]; u_mean_50 = Exact_[100]
X_u_test_75 = np.hstack([x, 0.75*np.ones_like((x))]); u_test_75 = Exact[150]; u_mean_75 = Exact_[150]


def get_res(X): 
    samples, noises = net.predict(X, 100, net.network)
    u_pred = samples.mean(axis = 0)

    aleatoric = (noises**2).mean(axis = 0)**0.5
    epistemic = samples.var(axis = 0)**0.5
    total_unc = (aleatoric**2 + epistemic**2)**0.5
    return u_pred.ravel(), aleatoric.ravel(), epistemic.ravel(), total_unc.ravel()


x = x.ravel()
u_pred_25, ale_25, epi_25, total_unc_25 = get_res(X_u_test_25)
u_pred_50, ale_50, epi_50, total_unc_50 = get_res(X_u_test_50)
u_pred_75, ale_75, epi_75, total_unc_75 = get_res(X_u_test_75)

# %%
fig, axs = plt.subplots(1, 3, figsize = (15,4))
axs[0].scatter(x, u_test_25, s = 10, marker = 'x', color = 'black', alpha = 0.5, label = 'Exact')
axs[0].plot(x, u_mean_25, 'b-', linewidth = 2, label = 'Prediction')
axs[0].plot(x, u_pred_25, 'r--', linewidth = 2, label = 'Prediction')
# axs[0].fill_between(x, u_pred_25-epi_25, u_pred_25+epi_25, color = 'g', alpha = 0.5, label = 'Epistemic + Aleatoric')
# axs[0].fill_between(x, u_pred_25-ale_25, u_pred_25+ale_25, color = 'g', alpha = 0.5, label = 'Epistemic + Aleatoric')
axs[0].fill_between(x, u_pred_25-2*total_unc_25, u_pred_25+2*total_unc_25, color = 'g', alpha = 0.5, label = 'Epistemic + Aleatoric')
axs[0].set_xlabel('$x$')
axs[0].set_ylabel('$u(t,x)$')
axs[0].set_title('$t = 0.25$', fontsize = 10)
# axs[0].set_xlim([-1.1,1.1])
# ax.set_ylim([-1.1,1.1])


axs[1].scatter(x, u_test_50, s = 10, marker = 'x', color = 'black', alpha = 0.5, label = 'Exact')
axs[1].plot(x, u_mean_50, 'b-', linewidth = 2, label = 'Prediction')
axs[1].plot(x, u_pred_50, 'r--', linewidth = 2, label = 'Prediction')
axs[1].fill_between(x, u_pred_50-2*total_unc_50, u_pred_50+2*total_unc_50, color = 'g', alpha = 0.5, label = 'Epistemic + Aleatoric')
axs[1].set_xlabel('$x$')
axs[1].set_ylabel('$u(t,x)$')
axs[1].set_title('$t = 0.5$', fontsize = 10)


axs[2].scatter(x, u_test_75, s = 10, marker = 'x', color = 'black', alpha = 0.5, label = 'Exact')
axs[2].plot(x, u_mean_75, 'b-', linewidth = 2, label = 'Prediction')
axs[2].plot(x, u_pred_75, 'r--', linewidth = 2, label = 'Prediction')
axs[2].fill_between(x, u_pred_75-2*total_unc_75, u_pred_75+2*total_unc_75, color = 'g', alpha = 0.5, label = 'Epistemic + Aleatoric')
axs[2].set_xlabel('$x$')
axs[2].set_ylabel('$u(t,x)$')
axs[2].set_title('$t = 0.75$', fontsize = 10)


plt.savefig('./plots/final_prediction_kdv.tiff')
